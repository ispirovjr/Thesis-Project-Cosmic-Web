# %%
import numpy as np
from matplotlib import pyplot as plt

import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch import nn

import vaex
import os

from cycler import cycler

# %% [markdown]
# for i in {0..2}; do python3 dataGenerator.py; done

# %%
plt.plot([1],[1])

font = {"weight": "normal", "size": 14}
plt.rcParams["axes.linewidth"] = 1.5  # set the value globally
plt.rc("font", **font)
plt.rcParams["axes.facecolor"] = "white"
plt.rcParams["figure.facecolor"] = "white"
_legend = {"frameon": True, "framealpha":0.7}
plt.rc("legend", **_legend)
plt.rcParams["axes.prop_cycle"] = cycler("color",('indigo','b','r','k','#ff7f0e','g'))
plt.show()

# %%
#path = "/net/virgo01/data/users/spirov/Blk/Nexus Project/torchData"
p2 = "/Users/users/spirov/Blk/Nexus Project/Thesis-Project-Cosmic-Web/Data/Training/"
p3 = "/Users/users/spirov/Blk/Nexus Project/Thesis-Project-Cosmic-Web/Data/Testing/"

# %%
df = vaex.open(p2+"1716300317.2928512.hdf5")

# %%
df
# Out:
# #        R                   Th                  Fi                   CZ
# 0        31646.162961670558  2.1390826590784418  2.2061568354611305   30482.8065700176
# 1        31501.54685289649   2.1876205480685087  2.269380145398704    31870.702325916347
# 2        32219.752614985406  2.149529474735148   2.1982821491320457   20277.255144189832
# 3        33237.35683278686   2.1872461862925983  2.220964807494919    27979.381651442367
# 4        30762.906318101057  2.1072605779979297  2.1834132393197123   30870.497193983945
# ...      ...                 ...                 ...                  ...
# 111,987  44489.51440048015   0.7633402998269055  -2.492251744360703   41646.55574536911
# 111,988  36933.7968317513    2.050070231118433   -3.1021895584564096  36674.09139869391
# 111,989  49928.165877541294  2.036494023736392   -2.181266890883465   50007.98241232911
# 111,990  32970.280079230724  1.6507252713084437  -2.725911735212825   32640.666805215893
# 111,991  45802.05345156686   2.0006786778815506  -2.2455826039034337  44960.73687294502

# %%
lim = 10
sc = 1e4

class CustomVaexDataset(Dataset):
    def __init__(self,frameDir):
        self.lengt = len(os.listdir(frameDir))
        self.frameDir = frameDir
    
    def __len__(self):
        return self.lengt
        
        
    def __getitem__(self,idx):
        fil = self.frameDir+os.listdir(self.frameDir)[idx]
        df = vaex.open(fil)
        
        th = df.Th.values[::lim]
        fi = df.Fi.values[::lim]
        R = df.R.values[::lim]/sc
        CZ = df.CZ.values[::lim]/sc
        
        broken = np.array((CZ,th,fi))
        truth = np.array(R)
        
        return torch.tensor(broken), torch.tensor(truth)

# %%
p2
# Out:
# '/Users/users/spirov/Blk/Nexus Project/Thesis-Project-Cosmic-Web/Data/Training/'

# %%
ds = CustomVaexDataset(p2)

# %%
a,b = ds.__getitem__(0)

# %%
a.size()
# Out:
# torch.Size([3, 11200])

# %%
b.size()
# Out:
# torch.Size([11200])

# %% [markdown]
# # Dloader

# %%
train_set = CustomVaexDataset(p2)
test_set = CustomVaexDataset(p3)

# %%
train_dataloader = DataLoader(train_set, batch_size=36, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size=12, shuffle=True)

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
# Out:
# Feature batch shape: torch.Size([36, 3, 11200])
# Labels batch shape: torch.Size([36, 11200])

# %%
img = train_features[0].squeeze()
label = train_labels[0]

# %%
plt.figure(figsize=(20,10))
plt.subplot(121,projection="polar")
plt.scatter(img[2],img[0],s=0.1*lim,alpha=0.7)
#plt.ylim(0,4e4)

plt.subplot(122,projection="polar")
plt.scatter(img[2],label,s=0.1*lim,alpha=0.7)
#plt.ylim(0,4e4)
plt.show()

# %% [markdown]
# # Neural Network

# %%
torch.set_default_dtype(img.dtype)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
n = int(2**12)
l=train_labels.size()[1]

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3 * l, n),
            nn.ReLU(),
            nn.Linear(n,n),
            nn.Sigmoid(),
            nn.Linear(n,n),
            nn.ReLU(),
            nn.Linear(n,n),
            nn.Sigmoid(),
            nn.Linear(n,n),
            nn.ReLU(),
            nn.Linear(n,l)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
Ls = []

def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 4 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: [{current:>5d}/{size:>5d}]  {loss:>7f}")


def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += ((pred.argmax(0) - y).abs()<bmark).type(torch.float).sum().item()

    test_loss /= num_batches
    
    correct /= size*y.size()[1] 
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    Ls.append(test_loss)

# %%
#hyperparams
learning_rate = 1e-1 #sc/1e5
batch_size = 16
epochs = 200
bmark = 1e3/sc
train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %%
loss_fn = nn.MSELoss() #
#loss_fn = nn.KLDivLoss()

model = NeuralNetwork()

# Adam either can't learn it proper or takes too long for right now. May explore with more comp power

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) 


for t in range(epochs):
    if t == 10:
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate*10) 
        
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: [   16/  512]  13.858391
# loss: [   80/  512]  13.237512
# loss: [  144/  512]  11.039558
# loss: [  208/  512]  5.027488
# loss: [  272/  512]  1.206194
# loss: [  336/  512]  1.119739
# loss: [  400/  512]  1.043537
# loss: [  464/  512]  1.118276
# Test Error:
#  Accuracy: 2.1%, Avg loss: 1.097428
#
# Epoch 2
# -------------------------------
# loss: [   16/  512]  1.079258
# loss: [   80/  512]  1.086250
# loss: [  144/  512]  1.074812
# loss: [  208/  512]  1.100586
# loss: [  272/  512]  1.074362
# loss: [  336/  512]  1.041874
# loss: [  400/  512]  1.098093
# loss: [  464/  512]  1.084689
# Test Error:
#  Accuracy: 0.7%, Avg loss: 1.101534
#
# Epoch 3
# -------------------------------
# loss: [   16/  512]  1.131596
# loss: [   80/  512]  1.119344
# loss: [  144/  512]  1.068530
# loss: [  208/  512]  1.103789
# loss: [  272/  512]  1.080432
# loss: [  336/  512]  1.053749
# loss: [  400/  512]  1.153624
# loss: [  464/  512]  1.074572
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.097049
#
# Epoch 4
# -------------------------------
# loss: [   16/  512]  1.109990
# loss: [   80/  512]  1.119957
# loss: [  144/  512]  1.079644
# loss: [  208/  512]  1.090352
# loss: [  272/  512]  1.059894
# loss: [  336/  512]  1.156185
# loss: [  400/  512]  1.064873
# loss: [  464/  512]  1.109237
# Test Error:
#  Accuracy: 1.6%, Avg loss: 1.096060
#
# Epoch 5
# -------------------------------
# loss: [   16/  512]  1.094641
# loss: [   80/  512]  1.115883
# loss: [  144/  512]  1.069132
# loss: [  208/  512]  1.069186
# loss: [  272/  512]  1.118449
# loss: [  336/  512]  1.081837
# loss: [  400/  512]  1.122066
# loss: [  464/  512]  1.042863
# Test Error:
#  Accuracy: 2.0%, Avg loss: 1.100106
#
# Epoch 6
# -------------------------------
# loss: [   16/  512]  1.072768
# loss: [   80/  512]  1.103511
# loss: [  144/  512]  1.109519
# loss: [  208/  512]  1.053147
# loss: [  272/  512]  1.134430
# loss: [  336/  512]  1.040165
# loss: [  400/  512]  1.063371
# loss: [  464/  512]  1.081453
# Test Error:
#  Accuracy: 2.1%, Avg loss: 1.094994
#
# Epoch 7
# -------------------------------
# loss: [   16/  512]  1.044909
# loss: [   80/  512]  1.088838
# loss: [  144/  512]  1.054145
# loss: [  208/  512]  1.153018
# loss: [  272/  512]  1.056111
# loss: [  336/  512]  1.024790
# loss: [  400/  512]  1.054866
# loss: [  464/  512]  1.093820
# Test Error:
#  Accuracy: 0.4%, Avg loss: 1.087507
#
# Epoch 8
# -------------------------------
# loss: [   16/  512]  1.054174
# loss: [   80/  512]  1.056994
# loss: [  144/  512]  1.184425
# loss: [  208/  512]  1.101133
# loss: [  272/  512]  1.073808
# loss: [  336/  512]  1.162957
# loss: [  400/  512]  1.088013
# loss: [  464/  512]  1.136835
# Test Error:
#  Accuracy: 0.3%, Avg loss: 1.097573
#
# Epoch 9
# -------------------------------
# loss: [   16/  512]  1.129553
# loss: [   80/  512]  1.107387
# loss: [  144/  512]  1.124246
# loss: [  208/  512]  1.103489
# loss: [  272/  512]  1.065385
# loss: [  336/  512]  1.092623
# loss: [  400/  512]  1.106691
# loss: [  464/  512]  1.145586
# Test Error:
#  Accuracy: 1.7%, Avg loss: 1.093760
#
# Epoch 10
# -------------------------------
# loss: [   16/  512]  1.046090
# loss: [   80/  512]  1.015295
# loss: [  144/  512]  1.083612
# loss: [  208/  512]  1.138707
# loss: [  272/  512]  1.072920
# loss: [  336/  512]  1.049042
# loss: [  400/  512]  1.124116
# loss: [  464/  512]  1.127905
# Test Error:
#  Accuracy: 0.9%, Avg loss: 1.093135
#
# Epoch 11
# -------------------------------
# loss: [   16/  512]  1.090427
# loss: [   80/  512]  1.135381
# loss: [  144/  512]  1.097491
# loss: [  208/  512]  1.048456
# loss: [  272/  512]  1.177199
# loss: [  336/  512]  1.077738
# loss: [  400/  512]  1.056837
# loss: [  464/  512]  1.085502
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.105370
#
# Epoch 12
# -------------------------------
# loss: [   16/  512]  1.070480
# loss: [   80/  512]  1.083111
# loss: [  144/  512]  1.126202
# loss: [  208/  512]  1.127811
# loss: [  272/  512]  1.064594
# loss: [  336/  512]  1.083209
# loss: [  400/  512]  1.123939
# loss: [  464/  512]  1.051412
# Test Error:
#  Accuracy: 2.3%, Avg loss: 1.087841
#
# Epoch 13
# -------------------------------
# loss: [   16/  512]  1.072642
# loss: [   80/  512]  1.094013
# loss: [  144/  512]  1.041600
# loss: [  208/  512]  1.073779
# loss: [  272/  512]  1.119599
# loss: [  336/  512]  1.070872
# loss: [  400/  512]  1.052877
# loss: [  464/  512]  1.038987
# Test Error:
#  Accuracy: 3.8%, Avg loss: 1.085461
#
# Epoch 14
# -------------------------------
# loss: [   16/  512]  1.037548
# loss: [   80/  512]  1.084873
# loss: [  144/  512]  1.093707
# loss: [  208/  512]  1.075863
# loss: [  272/  512]  1.092460
# loss: [  336/  512]  1.082794
# loss: [  400/  512]  1.091326
# loss: [  464/  512]  1.100461
# Test Error:
#  Accuracy: 1.6%, Avg loss: 1.104029
#
# Epoch 15
# -------------------------------
# loss: [   16/  512]  1.065199
# loss: [   80/  512]  1.176284
# loss: [  144/  512]  1.112968
# loss: [  208/  512]  1.071802
# loss: [  272/  512]  1.080233
# loss: [  336/  512]  1.076830
# loss: [  400/  512]  1.081084
# loss: [  464/  512]  1.093514
# Test Error:
#  Accuracy: 1.2%, Avg loss: 1.099390
#
# Epoch 16
# -------------------------------
# loss: [   16/  512]  1.126394
# loss: [   80/  512]  1.106345
# loss: [  144/  512]  1.042856
# loss: [  208/  512]  1.086866
# loss: [  272/  512]  1.069949
# loss: [  336/  512]  1.081153
# loss: [  400/  512]  1.165167
# loss: [  464/  512]  1.069715
# Test Error:
#  Accuracy: 2.1%, Avg loss: 1.084604
#
# Epoch 17
# -------------------------------
# loss: [   16/  512]  1.092631
# loss: [   80/  512]  1.095969
# loss: [  144/  512]  1.063390
# loss: [  208/  512]  1.103062
# loss: [  272/  512]  1.118912
# loss: [  336/  512]  1.062232
# loss: [  400/  512]  1.115133
# loss: [  464/  512]  1.037917
# Test Error:
#  Accuracy: 0.9%, Avg loss: 1.087630
#
# Epoch 18
# -------------------------------
# loss: [   16/  512]  1.087302
# loss: [   80/  512]  1.048738
# loss: [  144/  512]  1.129855
# loss: [  208/  512]  1.124622
# loss: [  272/  512]  1.107965
# loss: [  336/  512]  1.054969
# loss: [  400/  512]  1.074446
# loss: [  464/  512]  1.087011
# Test Error:
#  Accuracy: 1.6%, Avg loss: 1.086411
#
# Epoch 19
# -------------------------------
# loss: [   16/  512]  1.072433
# loss: [   80/  512]  1.082450
# loss: [  144/  512]  1.150186
# loss: [  208/  512]  1.072810
# loss: [  272/  512]  1.071210
# loss: [  336/  512]  1.076328
# loss: [  400/  512]  1.193096
# loss: [  464/  512]  1.063308
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.087141
#
# Epoch 20
# -------------------------------
# loss: [   16/  512]  1.104859
# loss: [   80/  512]  1.134243
# loss: [  144/  512]  1.078649
# loss: [  208/  512]  1.087686
# loss: [  272/  512]  1.095713
# loss: [  336/  512]  1.089728
# loss: [  400/  512]  1.061334
# loss: [  464/  512]  1.060678
# Test Error:
#  Accuracy: 0.7%, Avg loss: 1.085707
#
# Epoch 21
# -------------------------------
# loss: [   16/  512]  1.041386
# loss: [   80/  512]  1.090875
# loss: [  144/  512]  1.066758
# loss: [  208/  512]  1.100141
# loss: [  272/  512]  1.056236
# loss: [  336/  512]  1.080562
# loss: [  400/  512]  1.098614
# loss: [  464/  512]  1.039042
# Test Error:
#  Accuracy: 1.7%, Avg loss: 1.085739
#
# Epoch 22
# -------------------------------
# loss: [   16/  512]  1.021470
# loss: [   80/  512]  1.108265
# loss: [  144/  512]  1.110736
# loss: [  208/  512]  1.071472
# loss: [  272/  512]  1.084064
# loss: [  336/  512]  1.060480
# loss: [  400/  512]  1.095721
# loss: [  464/  512]  1.055241
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.089521
#
# Epoch 23
# -------------------------------
# loss: [   16/  512]  1.045973
# loss: [   80/  512]  1.035232
# loss: [  144/  512]  1.043473
# loss: [  208/  512]  1.083643
# loss: [  272/  512]  1.098463
# loss: [  336/  512]  1.157330
# loss: [  400/  512]  1.100948
# loss: [  464/  512]  1.120284
# Test Error:
#  Accuracy: 1.5%, Avg loss: 1.087613
#
# Epoch 24
# -------------------------------
# loss: [   16/  512]  1.089691
# loss: [   80/  512]  1.087163
# loss: [  144/  512]  1.059455
# loss: [  208/  512]  1.045639
# loss: [  272/  512]  1.069407
# loss: [  336/  512]  1.079776
# loss: [  400/  512]  1.076000
# loss: [  464/  512]  1.115096
# Test Error:
#  Accuracy: 2.1%, Avg loss: 1.096868
#
# Epoch 25
# -------------------------------
# loss: [   16/  512]  1.086215
# loss: [   80/  512]  1.067134
# loss: [  144/  512]  1.046278
# loss: [  208/  512]  1.097104
# loss: [  272/  512]  1.065109
# loss: [  336/  512]  1.059954
# loss: [  400/  512]  1.082723
# loss: [  464/  512]  1.043157
# Test Error:
#  Accuracy: 1.8%, Avg loss: 1.094030
#
# Epoch 26
# -------------------------------
# loss: [   16/  512]  1.084625
# loss: [   80/  512]  1.070669
# loss: [  144/  512]  1.069995
# loss: [  208/  512]  1.097738
# loss: [  272/  512]  1.095061
# loss: [  336/  512]  1.139151
# loss: [  400/  512]  1.124147
# loss: [  464/  512]  1.097956
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.081452
#
# Epoch 27
# -------------------------------
# loss: [   16/  512]  1.063550
# loss: [   80/  512]  1.058589
# loss: [  144/  512]  1.083988
# loss: [  208/  512]  1.116626
# loss: [  272/  512]  1.016307
# loss: [  336/  512]  1.085129
# loss: [  400/  512]  1.037047
# loss: [  464/  512]  1.100267
# Test Error:
#  Accuracy: 1.6%, Avg loss: 1.091197
#
# Epoch 28
# -------------------------------
# loss: [   16/  512]  1.064616
# loss: [   80/  512]  1.051427
# loss: [  144/  512]  1.072217
# loss: [  208/  512]  1.039861
# loss: [  272/  512]  1.113036
# loss: [  336/  512]  1.074781
# loss: [  400/  512]  1.102432
# loss: [  464/  512]  1.075484
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.091522
#
# Epoch 29
# -------------------------------
# loss: [   16/  512]  1.158988
# loss: [   80/  512]  1.059513
# loss: [  144/  512]  1.116350
# loss: [  208/  512]  1.045794
# loss: [  272/  512]  1.071960
# loss: [  336/  512]  1.088358
# loss: [  400/  512]  1.043122
# loss: [  464/  512]  1.093452
# Test Error:
#  Accuracy: 0.9%, Avg loss: 1.086846
#
# Epoch 30
# -------------------------------
# loss: [   16/  512]  1.046553
# loss: [   80/  512]  1.084953
# loss: [  144/  512]  1.123790
# loss: [  208/  512]  1.082593
# loss: [  272/  512]  1.098237
# loss: [  336/  512]  1.093462
# loss: [  400/  512]  1.102328
# loss: [  464/  512]  1.078345
# Test Error:
#  Accuracy: 0.2%, Avg loss: 1.084475
#
# Epoch 31
# -------------------------------
# loss: [   16/  512]  1.115431
# loss: [   80/  512]  1.065871
# loss: [  144/  512]  1.138618
# loss: [  208/  512]  1.094195
# loss: [  272/  512]  1.095201
# loss: [  336/  512]  1.019147
# loss: [  400/  512]  1.066503
# loss: [  464/  512]  1.119110
# Test Error:
#  Accuracy: 1.5%, Avg loss: 1.084155
#
# Epoch 32
# -------------------------------
# loss: [   16/  512]  1.057851
# loss: [   80/  512]  1.067345
# loss: [  144/  512]  1.033254
# loss: [  208/  512]  1.011823
# loss: [  272/  512]  1.085713
# loss: [  336/  512]  1.100372
# loss: [  400/  512]  1.147394
# loss: [  464/  512]  1.100270
# Test Error:
#  Accuracy: 0.2%, Avg loss: 1.084524
#
# Epoch 33
# -------------------------------
# loss: [   16/  512]  1.062082
# loss: [   80/  512]  1.082488
# loss: [  144/  512]  1.025915
# loss: [  208/  512]  1.028325
# loss: [  272/  512]  1.044088
# loss: [  336/  512]  1.039511
# loss: [  400/  512]  1.054161
# loss: [  464/  512]  1.081953
# Test Error:
#  Accuracy: 0.5%, Avg loss: 1.092144
#
# Epoch 34
# -------------------------------
# loss: [   16/  512]  1.075271
# loss: [   80/  512]  1.092319
# loss: [  144/  512]  1.074564
# loss: [  208/  512]  1.117278
# loss: [  272/  512]  1.143578
# loss: [  336/  512]  1.059826
# loss: [  400/  512]  1.066325
# loss: [  464/  512]  1.074896
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.098131
#
# Epoch 35
# -------------------------------
# loss: [   16/  512]  1.072070
# loss: [   80/  512]  1.053231
# loss: [  144/  512]  1.091722
# loss: [  208/  512]  1.080403
# loss: [  272/  512]  1.124555
# loss: [  336/  512]  1.067812
# loss: [  400/  512]  1.055542
# loss: [  464/  512]  1.094994
# Test Error:
#  Accuracy: 1.0%, Avg loss: 1.083561
#
# Epoch 36
# -------------------------------
# loss: [   16/  512]  1.052215
# loss: [   80/  512]  1.104973
# loss: [  144/  512]  1.058904
# loss: [  208/  512]  1.080357
# loss: [  272/  512]  1.128848
# loss: [  336/  512]  1.055376
# loss: [  400/  512]  1.125316
# loss: [  464/  512]  1.103761
# Test Error:
#  Accuracy: 0.6%, Avg loss: 1.091027
#
# Epoch 37
# -------------------------------
# loss: [   16/  512]  1.077369
# loss: [   80/  512]  1.044179
# loss: [  144/  512]  1.082093
# loss: [  208/  512]  1.166878
# loss: [  272/  512]  1.089692
# loss: [  336/  512]  1.048335
# loss: [  400/  512]  1.102938
# loss: [  464/  512]  1.090706
# Test Error:
#  Accuracy: 0.6%, Avg loss: 1.082860
#
# Epoch 38
# -------------------------------
# loss: [   16/  512]  1.016862
# loss: [   80/  512]  1.123701
# loss: [  144/  512]  1.075923
# loss: [  208/  512]  1.015650
# loss: [  272/  512]  1.096739
# loss: [  336/  512]  1.167522
# loss: [  400/  512]  1.075269
# loss: [  464/  512]  1.041064
# Test Error:
#  Accuracy: 0.7%, Avg loss: 1.088204
#
# Epoch 39
# -------------------------------
# loss: [   16/  512]  1.090142
# loss: [   80/  512]  1.130517
# loss: [  144/  512]  1.070762
# loss: [  208/  512]  1.059425
# loss: [  272/  512]  1.071771
# loss: [  336/  512]  0.980788
# loss: [  400/  512]  1.076631
# loss: [  464/  512]  1.113370
# Test Error:
#  Accuracy: 0.6%, Avg loss: 1.088504
#
# Epoch 40
# -------------------------------
# loss: [   16/  512]  1.098615
# loss: [   80/  512]  1.078986
# loss: [  144/  512]  1.125535
# loss: [  208/  512]  1.098021
# loss: [  272/  512]  1.104007
# loss: [  336/  512]  1.025170
# loss: [  400/  512]  1.130021
# loss: [  464/  512]  1.063181
# Test Error:
#  Accuracy: 3.0%, Avg loss: 1.089103
#
# Epoch 41
# -------------------------------
# loss: [   16/  512]  1.000903
# loss: [   80/  512]  1.070040
# loss: [  144/  512]  1.104864
# loss: [  208/  512]  1.083169
# loss: [  272/  512]  1.085609
# loss: [  336/  512]  1.073720
# loss: [  400/  512]  1.081857
# loss: [  464/  512]  1.080748
# Test Error:
#  Accuracy: 0.0%, Avg loss: 1.082865
#
# Epoch 42
# -------------------------------
# loss: [   16/  512]  1.096358
# loss: [   80/  512]  1.065113
# loss: [  144/  512]  1.104929
# loss: [  208/  512]  1.074448
# loss: [  272/  512]  1.085858
# loss: [  336/  512]  1.137225
# loss: [  400/  512]  1.045163
# loss: [  464/  512]  1.039243
# Test Error:
#  Accuracy: 1.0%, Avg loss: 1.092469
#
# Epoch 43
# -------------------------------
# loss: [   16/  512]  1.096797
# loss: [   80/  512]  1.115574
# loss: [  144/  512]  1.038405
# loss: [  208/  512]  1.094786
# loss: [  272/  512]  1.059128
# loss: [  336/  512]  1.062423
# loss: [  400/  512]  1.020598
# loss: [  464/  512]  1.134190
# Test Error:
#  Accuracy: 1.2%, Avg loss: 1.086132
#
# Epoch 44
# -------------------------------
# loss: [   16/  512]  1.097822
# loss: [   80/  512]  1.082247
# loss: [  144/  512]  1.095711
# loss: [  208/  512]  1.074602
# loss: [  272/  512]  1.053216
# loss: [  336/  512]  1.067422
# loss: [  400/  512]  1.121748
# loss: [  464/  512]  1.033987
# Test Error:
#  Accuracy: 0.8%, Avg loss: 1.089521
#
# Epoch 45
# -------------------------------
# loss: [   16/  512]  1.045178
# loss: [   80/  512]  1.064916
# loss: [  144/  512]  1.085729
# loss: [  208/  512]  1.055433
# loss: [  272/  512]  1.141987
# loss: [  336/  512]  1.050971
# loss: [  400/  512]  1.064757
# loss: [  464/  512]  1.118122
# Test Error:
#  Accuracy: 0.9%, Avg loss: 1.086840
#
# Epoch 46
# -------------------------------
# loss: [   16/  512]  1.065741
# loss: [   80/  512]  1.081685
# loss: [  144/  512]  1.089901
# loss: [  208/  512]  1.098086
# loss: [  272/  512]  1.045718
# loss: [  336/  512]  1.030461
# loss: [  400/  512]  1.025793
# loss: [  464/  512]  1.108121
# Test Error:
#  Accuracy: 1.9%, Avg loss: 1.091399
#
# Epoch 47
# -------------------------------
# loss: [   16/  512]  1.084825
# loss: [   80/  512]  1.050973
# loss: [  144/  512]  1.057479
# loss: [  208/  512]  1.022178
# loss: [  272/  512]  1.102907
# loss: [  336/  512]  1.067654
# loss: [  400/  512]  1.028395
# loss: [  464/  512]  1.094215
# Test Error:
#  Accuracy: 0.0%, Avg loss: 1.087825
#
# Epoch 48
# -------------------------------
# loss: [   16/  512]  1.077548
# loss: [   80/  512]  1.068708
# loss: [  144/  512]  1.028760
# loss: [  208/  512]  1.049800
# loss: [  272/  512]  1.095848
# loss: [  336/  512]  1.140103
# loss: [  400/  512]  1.079724
# loss: [  464/  512]  1.012632
# Test Error:
#  Accuracy: 0.4%, Avg loss: 1.088460
#
# Epoch 49
# -------------------------------
# loss: [   16/  512]  1.055167
# loss: [   80/  512]  1.055090
# loss: [  144/  512]  1.102951
# loss: [  208/  512]  1.083032
# loss: [  272/  512]  1.101162
# loss: [  336/  512]  1.155741
# loss: [  400/  512]  1.038176
# loss: [  464/  512]  1.091245
# Test Error:
#  Accuracy: 1.2%, Avg loss: 1.087049
#
# Epoch 50
# -------------------------------
# loss: [   16/  512]  1.073511
# loss: [   80/  512]  1.034064
# loss: [  144/  512]  1.071579
# loss: [  208/  512]  1.120672
# loss: [  272/  512]  1.063245
# loss: [  336/  512]  1.042356
# loss: [  400/  512]  1.095826
# loss: [  464/  512]  1.058829
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.082118
#
# Epoch 51
# -------------------------------
# loss: [   16/  512]  1.066854
# loss: [   80/  512]  1.066528
# loss: [  144/  512]  1.190771
# loss: [  208/  512]  1.094735
# loss: [  272/  512]  1.021856
# loss: [  336/  512]  1.088071
# loss: [  400/  512]  1.134538
# loss: [  464/  512]  1.046170
# Test Error:
#  Accuracy: 0.8%, Avg loss: 1.080298
#
# Epoch 52
# -------------------------------
# loss: [   16/  512]  1.042838
# loss: [   80/  512]  1.032802
# loss: [  144/  512]  1.117013
# loss: [  208/  512]  1.109174
# loss: [  272/  512]  1.070414
# loss: [  336/  512]  1.068231
# loss: [  400/  512]  1.081310
# loss: [  464/  512]  1.092506
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.086065
#
# Epoch 53
# -------------------------------
# loss: [   16/  512]  1.039372
# loss: [   80/  512]  1.007615
# loss: [  144/  512]  1.071424
# loss: [  208/  512]  1.108989
# loss: [  272/  512]  1.065015
# loss: [  336/  512]  1.051942
# loss: [  400/  512]  1.065732
# loss: [  464/  512]  1.077249
# Test Error:
#  Accuracy: 1.0%, Avg loss: 1.085525
#
# Epoch 54
# -------------------------------
# loss: [   16/  512]  1.094433
# loss: [   80/  512]  1.043621
# loss: [  144/  512]  1.025437
# loss: [  208/  512]  1.089674
# loss: [  272/  512]  1.100619
# loss: [  336/  512]  1.048675
# loss: [  400/  512]  1.085776
# loss: [  464/  512]  1.080978
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.090120
#
# Epoch 55
# -------------------------------
# loss: [   16/  512]  1.055993
# loss: [   80/  512]  1.039536
# loss: [  144/  512]  1.079527
# loss: [  208/  512]  1.143232
# loss: [  272/  512]  1.089979
# loss: [  336/  512]  1.060202
# loss: [  400/  512]  1.068201
# loss: [  464/  512]  1.054667
# Test Error:
#  Accuracy: 1.2%, Avg loss: 1.080037
#
# Epoch 56
# -------------------------------
# loss: [   16/  512]  1.086209
# loss: [   80/  512]  1.118406
# loss: [  144/  512]  1.057868
# loss: [  208/  512]  1.129296
# loss: [  272/  512]  1.041970
# loss: [  336/  512]  1.116325
# loss: [  400/  512]  1.054445
# loss: [  464/  512]  1.053453
# Test Error:
#  Accuracy: 0.6%, Avg loss: 1.081528
#
# Epoch 57
# -------------------------------
# loss: [   16/  512]  1.066305
# loss: [   80/  512]  1.056358
# loss: [  144/  512]  1.138539
# loss: [  208/  512]  1.100051
# loss: [  272/  512]  1.089627
# loss: [  336/  512]  1.134677
# loss: [  400/  512]  1.006974
# loss: [  464/  512]  1.071521
# Test Error:
#  Accuracy: 0.6%, Avg loss: 1.091481
#
# Epoch 58
# -------------------------------
# loss: [   16/  512]  1.103889
# loss: [   80/  512]  1.072481
# loss: [  144/  512]  1.068685
# loss: [  208/  512]  1.149414
# loss: [  272/  512]  1.107720
# loss: [  336/  512]  1.077752
# loss: [  400/  512]  1.023375
# loss: [  464/  512]  1.108311
# Test Error:
#  Accuracy: 1.4%, Avg loss: 1.083044
#
# Epoch 59
# -------------------------------
# loss: [   16/  512]  1.050375
# loss: [   80/  512]  1.030146
# loss: [  144/  512]  1.072348
# loss: [  208/  512]  1.100951
# loss: [  272/  512]  1.091824
# loss: [  336/  512]  1.055119
# loss: [  400/  512]  1.039868
# loss: [  464/  512]  1.061010
# Test Error:
#  Accuracy: 1.5%, Avg loss: 1.089660
#
# Epoch 60
# -------------------------------
# loss: [   16/  512]  1.075121
# loss: [   80/  512]  1.077206
# loss: [  144/  512]  1.117738
# loss: [  208/  512]  1.049004
# loss: [  272/  512]  1.083846
# loss: [  336/  512]  1.109801
# loss: [  400/  512]  1.089346
# loss: [  464/  512]  1.077148
# Test Error:
#  Accuracy: 0.7%, Avg loss: 1.079276
#
# Epoch 61
# -------------------------------
# loss: [   16/  512]  1.142613
# loss: [   80/  512]  1.121127
# loss: [  144/  512]  1.080564
# loss: [  208/  512]  1.007844
# loss: [  272/  512]  1.071002
# loss: [  336/  512]  1.096033
# loss: [  400/  512]  1.035871
# loss: [  464/  512]  1.079729
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.081926
#
# Epoch 62
# -------------------------------
# loss: [   16/  512]  1.065474
# loss: [   80/  512]  1.022416
# loss: [  144/  512]  1.109828
# loss: [  208/  512]  1.011721
# loss: [  272/  512]  1.093380
# loss: [  336/  512]  1.032673
# loss: [  400/  512]  1.098542
# loss: [  464/  512]  1.078980
# Test Error:
#  Accuracy: 1.2%, Avg loss: 1.084430
#
# Epoch 63
# -------------------------------
# loss: [   16/  512]  1.036485
# loss: [   80/  512]  1.104923
# loss: [  144/  512]  1.072867
# loss: [  208/  512]  1.085062
# loss: [  272/  512]  1.044798
# loss: [  336/  512]  0.980116
# loss: [  400/  512]  1.063715
# loss: [  464/  512]  1.088572
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.074396
#
# Epoch 64
# -------------------------------
# loss: [   16/  512]  1.023883
# loss: [   80/  512]  1.009242
# loss: [  144/  512]  1.139558
# loss: [  208/  512]  1.117544
# loss: [  272/  512]  1.035614
# loss: [  336/  512]  1.107513
# loss: [  400/  512]  1.063125
# loss: [  464/  512]  1.095476
# Test Error:
#  Accuracy: 2.3%, Avg loss: 1.069875
#
# Epoch 65
# -------------------------------
# loss: [   16/  512]  1.029127
# loss: [   80/  512]  1.021558
# loss: [  144/  512]  0.965836
# loss: [  208/  512]  1.089097
# loss: [  272/  512]  1.124248
# loss: [  336/  512]  1.047234
# loss: [  400/  512]  1.078037
# loss: [  464/  512]  1.078556
# Test Error:
#  Accuracy: 0.3%, Avg loss: 1.077894
#
# Epoch 66
# -------------------------------
# loss: [   16/  512]  1.096850
# loss: [   80/  512]  1.092108
# loss: [  144/  512]  1.071434
# loss: [  208/  512]  1.058893
# loss: [  272/  512]  1.036756
# loss: [  336/  512]  1.029613
# loss: [  400/  512]  1.041332
# loss: [  464/  512]  1.060116
# Test Error:
#  Accuracy: 1.3%, Avg loss: 1.074927
#
# Epoch 67
# -------------------------------
# loss: [   16/  512]  1.074202
# loss: [   80/  512]  1.005641
# loss: [  144/  512]  1.053802
# loss: [  208/  512]  1.089557
# loss: [  272/  512]  1.065359
# loss: [  336/  512]  1.049106
# loss: [  400/  512]  1.091480
# loss: [  464/  512]  1.058931
# Test Error:
#  Accuracy: 1.1%, Avg loss: 1.073944
#
# Epoch 68
# -------------------------------
# loss: [   16/  512]  1.020017
# loss: [   80/  512]  1.135613
# loss: [  144/  512]  1.129331
# loss: [  208/  512]  1.018467
# loss: [  272/  512]  1.071397
# loss: [  336/  512]  1.049387
# loss: [  400/  512]  1.080698
# loss: [  464/  512]  1.080174
# Test Error:
#  Accuracy: 0.8%, Avg loss: 1.063684
#
# Epoch 69
# -------------------------------
# loss: [   16/  512]  1.030072
# loss: [   80/  512]  1.102303
# loss: [  144/  512]  1.089629
# loss: [  208/  512]  1.042312
# loss: [  272/  512]  0.987598
# loss: [  336/  512]  1.048952
# loss: [  400/  512]  1.080084
# loss: [  464/  512]  0.969562
# Test Error:
#  Accuracy: 2.1%, Avg loss: 1.055158
#
# Epoch 70
# -------------------------------
# loss: [   16/  512]  1.055721
# loss: [   80/  512]  1.048345
# loss: [  144/  512]  1.074377
# loss: [  208/  512]  1.034443
# loss: [  272/  512]  1.078273
# loss: [  336/  512]  0.992408
# loss: [  400/  512]  1.021231
# loss: [  464/  512]  1.012049
# Test Error:
#  Accuracy: 0.4%, Avg loss: 1.046361
#
# Epoch 71
# -------------------------------
# loss: [   16/  512]  1.029619
# loss: [   80/  512]  1.023240
# loss: [  144/  512]  1.042700
# loss: [  208/  512]  1.065162
# loss: [  272/  512]  1.007807
# loss: [  336/  512]  1.042758
# loss: [  400/  512]  0.957343
# loss: [  464/  512]  1.048112
# Test Error:
#  Accuracy: 1.8%, Avg loss: 1.034267
#
# Epoch 72
# -------------------------------
# loss: [   16/  512]  0.987526
# loss: [   80/  512]  1.079657
# loss: [  144/  512]  1.013250
# loss: [  208/  512]  0.998094
# loss: [  272/  512]  1.002108
# loss: [  336/  512]  0.989525
# loss: [  400/  512]  0.982627
# loss: [  464/  512]  0.970008
# Test Error:
#  Accuracy: 1.4%, Avg loss: 1.010622
#
# Epoch 73
# -------------------------------
# loss: [   16/  512]  0.961850
# loss: [   80/  512]  1.049410
# loss: [  144/  512]  0.961257
# loss: [  208/  512]  0.987264
# loss: [  272/  512]  0.954043
# loss: [  336/  512]  1.031369
# loss: [  400/  512]  0.986782
# loss: [  464/  512]  0.912061
# Test Error:
#  Accuracy: 0.9%, Avg loss: 0.990828
#
# Epoch 74
# -------------------------------
# loss: [   16/  512]  1.053648
# loss: [   80/  512]  0.940998
# loss: [  144/  512]  0.937056
# loss: [  208/  512]  0.978613
# loss: [  272/  512]  0.949296
# loss: [  336/  512]  0.922506
# loss: [  400/  512]  0.986592
# loss: [  464/  512]  0.958789
# Test Error:
#  Accuracy: 1.0%, Avg loss: 0.956215
#
# Epoch 75
# -------------------------------
# loss: [   16/  512]  0.947001
# loss: [   80/  512]  0.903510
# loss: [  144/  512]  0.960859
# loss: [  208/  512]  0.944474
# loss: [  272/  512]  0.868327
# loss: [  336/  512]  0.884238
# loss: [  400/  512]  0.941979
# loss: [  464/  512]  0.932733
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.936793
#
# Epoch 76
# -------------------------------
# loss: [   16/  512]  0.961100
# loss: [   80/  512]  0.853124
# loss: [  144/  512]  0.866517
# loss: [  208/  512]  0.925464
# loss: [  272/  512]  0.912159
# loss: [  336/  512]  0.902733
# loss: [  400/  512]  0.948619
# loss: [  464/  512]  0.920160
# Test Error:
#  Accuracy: 1.3%, Avg loss: 0.927634
#
# Epoch 77
# -------------------------------
# loss: [   16/  512]  0.925384
# loss: [   80/  512]  0.915234
# loss: [  144/  512]  0.855427
# loss: [  208/  512]  0.899159
# loss: [  272/  512]  0.943392
# loss: [  336/  512]  0.853353
# loss: [  400/  512]  0.965603
# loss: [  464/  512]  0.947469
# Test Error:
#  Accuracy: 0.8%, Avg loss: 0.913585
#
# Epoch 78
# -------------------------------
# loss: [   16/  512]  0.909898
# loss: [   80/  512]  0.826555
# loss: [  144/  512]  0.869441
# loss: [  208/  512]  0.887921
# loss: [  272/  512]  0.914734
# loss: [  336/  512]  0.894427
# loss: [  400/  512]  0.875682
# loss: [  464/  512]  0.849530
# Test Error:
#  Accuracy: 0.7%, Avg loss: 0.903992
#
# Epoch 79
# -------------------------------
# loss: [   16/  512]  0.899187
# loss: [   80/  512]  0.914570
# loss: [  144/  512]  0.928960
# loss: [  208/  512]  0.883308
# loss: [  272/  512]  0.850587
# loss: [  336/  512]  0.885429
# loss: [  400/  512]  0.859712
# loss: [  464/  512]  0.810331
# Test Error:
#  Accuracy: 0.8%, Avg loss: 0.894900
#
# Epoch 80
# -------------------------------
# loss: [   16/  512]  0.889977
# loss: [   80/  512]  0.833684
# loss: [  144/  512]  0.820375
# loss: [  208/  512]  0.876648
# loss: [  272/  512]  0.852726
# loss: [  336/  512]  0.829828
# loss: [  400/  512]  0.839168
# loss: [  464/  512]  0.874407
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.880644
#
# Epoch 81
# -------------------------------
# loss: [   16/  512]  0.848636
# loss: [   80/  512]  0.830701
# loss: [  144/  512]  0.819632
# loss: [  208/  512]  0.847908
# loss: [  272/  512]  0.853321
# loss: [  336/  512]  0.902760
# loss: [  400/  512]  0.807177
# loss: [  464/  512]  0.802587
# Test Error:
#  Accuracy: 1.3%, Avg loss: 0.867765
#
# Epoch 82
# -------------------------------
# loss: [   16/  512]  0.797816
# loss: [   80/  512]  0.827720
# loss: [  144/  512]  0.785853
# loss: [  208/  512]  0.841283
# loss: [  272/  512]  0.831237
# loss: [  336/  512]  0.782943
# loss: [  400/  512]  0.864389
# loss: [  464/  512]  0.810473
# Test Error:
#  Accuracy: 1.1%, Avg loss: 0.855066
#
# Epoch 83
# -------------------------------
# loss: [   16/  512]  0.836978
# loss: [   80/  512]  0.799474
# loss: [  144/  512]  0.771623
# loss: [  208/  512]  0.839450
# loss: [  272/  512]  0.810889
# loss: [  336/  512]  0.765117
# loss: [  400/  512]  0.791042
# loss: [  464/  512]  0.847532
# Test Error:
#  Accuracy: 1.9%, Avg loss: 0.835020
#
# Epoch 84
# -------------------------------
# loss: [   16/  512]  0.772573
# loss: [   80/  512]  0.827398
# loss: [  144/  512]  0.843469
# loss: [  208/  512]  0.773038
# loss: [  272/  512]  0.785831
# loss: [  336/  512]  0.791430
# loss: [  400/  512]  0.751315
# loss: [  464/  512]  0.783526
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.815637
#
# Epoch 85
# -------------------------------
# loss: [   16/  512]  0.787031
# loss: [   80/  512]  0.772214
# loss: [  144/  512]  0.744776
# loss: [  208/  512]  0.711734
# loss: [  272/  512]  0.768940
# loss: [  336/  512]  0.703855
# loss: [  400/  512]  0.753174
# loss: [  464/  512]  0.722163
# Test Error:
#  Accuracy: 1.5%, Avg loss: 0.806513
#
# Epoch 86
# -------------------------------
# loss: [   16/  512]  0.757804
# loss: [   80/  512]  0.731453
# loss: [  144/  512]  0.767143
# loss: [  208/  512]  0.803592
# loss: [  272/  512]  0.753881
# loss: [  336/  512]  0.792876
# loss: [  400/  512]  0.786441
# loss: [  464/  512]  0.786854
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.790256
#
# Epoch 87
# -------------------------------
# loss: [   16/  512]  0.708821
# loss: [   80/  512]  0.817101
# loss: [  144/  512]  0.670954
# loss: [  208/  512]  0.725069
# loss: [  272/  512]  0.783138
# loss: [  336/  512]  0.664756
# loss: [  400/  512]  0.741951
# loss: [  464/  512]  0.732002
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.775639
#
# Epoch 88
# -------------------------------
# loss: [   16/  512]  0.718232
# loss: [   80/  512]  0.759807
# loss: [  144/  512]  0.754260
# loss: [  208/  512]  0.792907
# loss: [  272/  512]  0.683144
# loss: [  336/  512]  0.650834
# loss: [  400/  512]  0.717503
# loss: [  464/  512]  0.751807
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.754802
#
# Epoch 89
# -------------------------------
# loss: [   16/  512]  0.763216
# loss: [   80/  512]  0.732594
# loss: [  144/  512]  0.653277
# loss: [  208/  512]  0.716091
# loss: [  272/  512]  0.746844
# loss: [  336/  512]  0.666266
# loss: [  400/  512]  0.704266
# loss: [  464/  512]  0.667537
# Test Error:
#  Accuracy: 1.5%, Avg loss: 0.737538
#
# Epoch 90
# -------------------------------
# loss: [   16/  512]  0.653549
# loss: [   80/  512]  0.681476
# loss: [  144/  512]  0.655934
# loss: [  208/  512]  0.639722
# loss: [  272/  512]  0.700885
# loss: [  336/  512]  0.692831
# loss: [  400/  512]  0.734059
# loss: [  464/  512]  0.658798
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.711731
#
# Epoch 91
# -------------------------------
# loss: [   16/  512]  0.598134
# loss: [   80/  512]  0.732757
# loss: [  144/  512]  0.692438
# loss: [  208/  512]  0.707589
# loss: [  272/  512]  0.590418
# loss: [  336/  512]  0.634314
# loss: [  400/  512]  0.670351
# loss: [  464/  512]  0.628416
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.688135
#
# Epoch 92
# -------------------------------
# loss: [   16/  512]  0.699211
# loss: [   80/  512]  0.681695
# loss: [  144/  512]  0.665180
# loss: [  208/  512]  0.507471
# loss: [  272/  512]  0.637086
# loss: [  336/  512]  0.667812
# loss: [  400/  512]  0.657468
# loss: [  464/  512]  0.625128
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.666392
#
# Epoch 93
# -------------------------------
# loss: [   16/  512]  0.676758
# loss: [   80/  512]  0.618340
# loss: [  144/  512]  0.600453
# loss: [  208/  512]  0.651494
# loss: [  272/  512]  0.547929
# loss: [  336/  512]  0.611533
# loss: [  400/  512]  0.552878
# loss: [  464/  512]  0.655662
# Test Error:
#  Accuracy: 1.0%, Avg loss: 0.671845
#
# Epoch 94
# -------------------------------
# loss: [   16/  512]  0.657398
# loss: [   80/  512]  0.552188
# loss: [  144/  512]  0.567909
# loss: [  208/  512]  0.613260
# loss: [  272/  512]  0.655155
# loss: [  336/  512]  0.587237
# loss: [  400/  512]  0.550927
# loss: [  464/  512]  0.625523
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.628489
#
# Epoch 95
# -------------------------------
# loss: [   16/  512]  0.577939
# loss: [   80/  512]  0.503336
# loss: [  144/  512]  0.560397
# loss: [  208/  512]  0.587097
# loss: [  272/  512]  0.602442
# loss: [  336/  512]  0.561755
# loss: [  400/  512]  0.536703
# loss: [  464/  512]  0.604466
# Test Error:
#  Accuracy: 1.3%, Avg loss: 0.614398
#
# Epoch 96
# -------------------------------
# loss: [   16/  512]  0.609269
# loss: [   80/  512]  0.511821
# loss: [  144/  512]  0.579436
# loss: [  208/  512]  0.559407
# loss: [  272/  512]  0.478117
# loss: [  336/  512]  0.587668
# loss: [  400/  512]  0.544340
# loss: [  464/  512]  0.584037
# Test Error:
#  Accuracy: 1.2%, Avg loss: 0.609003
#
# Epoch 97
# -------------------------------
# loss: [   16/  512]  0.561205
# loss: [   80/  512]  0.635376
# loss: [  144/  512]  0.614259
# loss: [  208/  512]  0.556244
# loss: [  272/  512]  0.516150
# loss: [  336/  512]  0.474273
# loss: [  400/  512]  0.570056
# loss: [  464/  512]  0.617467
# Test Error:
#  Accuracy: 0.8%, Avg loss: 0.603205
#
# Epoch 98
# -------------------------------
# loss: [   16/  512]  0.595194
# loss: [   80/  512]  0.557373
# loss: [  144/  512]  0.530857
# loss: [  208/  512]  0.504237
# loss: [  272/  512]  0.621784
# loss: [  336/  512]  0.541287
# loss: [  400/  512]  0.608549
# loss: [  464/  512]  0.674598
# Test Error:
#  Accuracy: 1.0%, Avg loss: 0.593179
#
# Epoch 99
# -------------------------------
# loss: [   16/  512]  0.554188
# loss: [   80/  512]  0.574921
# loss: [  144/  512]  0.611744
# loss: [  208/  512]  0.539237
# loss: [  272/  512]  0.525602
# loss: [  336/  512]  0.558915
# loss: [  400/  512]  0.568565
# loss: [  464/  512]  0.670040
# Test Error:
#  Accuracy: 1.4%, Avg loss: 0.598645
#
# Epoch 100
# -------------------------------
# loss: [   16/  512]  0.609703
# loss: [   80/  512]  0.585917
# loss: [  144/  512]  0.567786
# loss: [  208/  512]  0.506233
# loss: [  272/  512]  0.536190
# loss: [  336/  512]  0.430918
# loss: [  400/  512]  0.526884
# loss: [  464/  512]  0.569837
# Test Error:
#  Accuracy: 1.3%, Avg loss: 0.585791
#
# Epoch 101
# -------------------------------
# loss: [   16/  512]  0.535060
# loss: [   80/  512]  0.527400
# loss: [  144/  512]  0.546201
# loss: [  208/  512]  0.557730
# loss: [  272/  512]  0.494373
# loss: [  336/  512]  0.495020
# loss: [  400/  512]  0.628448
# loss: [  464/  512]  0.583701
# Test Error:
#  Accuracy: 1.3%, Avg loss: 0.591731
#
# Epoch 102
# -------------------------------
# loss: [   16/  512]  0.575739
# loss: [   80/  512]  0.511746
# loss: [  144/  512]  0.599105
# loss: [  208/  512]  0.526801
# loss: [  272/  512]  0.658566
# loss: [  336/  512]  0.540135
# loss: [  400/  512]  0.635225
# loss: [  464/  512]  0.484237
# Test Error:
#  Accuracy: 1.1%, Avg loss: 0.579049
#
# Epoch 103
# -------------------------------
# loss: [   16/  512]  0.529549
# loss: [   80/  512]  0.515041

# %%
zp=0

plt.plot((Ls[zp:]))
plt.title(f"1e{np.log10(sc)} with large dataset")
#plt.yscale('log')
plt.show()
plt.plot(np.diff(Ls[zp:]),marker='+')
plt.title(f"Rough Derivative")
plt.axhline(0)
#plt.yscale('symlog')
#plt.yscale('log')
plt.show()
plt.plot((Ls[zp+25:]))
plt.title(f"Zoom 1e{np.log10(sc)} with large dataset")
#plt.yscale('log')
plt.show()

# %%
train_features, train_labels = next(iter(train_dataloader))
img = train_features[0].squeeze()
label = train_labels[0]

with torch.no_grad():
    mod = model(train_features)[0]

plt.figure(figsize=(30,10))
plt.subplot(131,projection="polar")
plt.scatter(img[2],img[0],s=0.1*lim,alpha=0.7)
#plt.ylim(0,4e4)
plt.title("Broken")

plt.subplot(132,projection="polar")
plt.scatter(img[2],mod,s=0.1*lim,alpha=0.7)
plt.title("Model")

plt.subplot(133,projection="polar")
plt.scatter(img[2],label,s=0.1*lim,alpha=0.7)
#plt.ylim(0,4e4)
plt.title("Correct")

plt.suptitle("200 Epochs SGD, 6 linear")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(projection="polar")
plt.scatter(img[2],mod,s=0.1*lim,alpha=0.7,label="Model")

plt.scatter(img[2],label,s=0.1*lim,alpha=0.7,label="Truth")
#plt.ylim(0,4e4)
plt.title("Comparison")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(121,projection="polar")
plt.scatter(img[2],(mod-mod.min())*15,s=0.1*lim,alpha=0.7,label="Model")

plt.title("Test")


plt.subplot(122,projection="polar")
plt.scatter(img[2],label,s=0.1*lim,alpha=0.7,label="Truth")
#plt.ylim(0,4e4)
plt.title("Truth")

plt.show()

# %% [markdown]
# # Goals:
#
#
#
# > ~create dataset of some size~
#
# > ~load data~
#
# > construct model with appropriate architecture

# %% [markdown]
# Save:
#
# torch.save(model.state_dict(), PATH)
#
#
# Load:
#
# model = TheModelClass(*args, **kwargs)
# model.load_state_dict(torch.load(PATH))
# model.eval()
